# %% [markdown]
# install the following packages:
# pix2tex, IPython, PIL

# %%
from PIL import Image
from pix2tex.cli import LatexOCR
from IPython.display import display, Latex

# %% [markdown]
# file: num6.png:
#
# ![image.png](attachment:image.png)

# %%
file = "num6.png"
img = Image.open(file)

model = LatexOCR()
a = model(img)

display(Latex(f"$%s$"%a))
# Out:
# ${\cal W}=\frac{\Psi^{\prime}{}^{2}q b}{2\mu_{0}}\left[\mu^{2}+\sum_{m,n}\left(\frac{a_{\pi n n}^{2}}{4}\left(\frac{n^{2}\pi^{2}}{a^{2}}+\frac{n^{2}\pi^{2}}{b^{2}}+\mu^{2}\right)+\frac{8a_{m n}\mu^{2}}{\pi^{2}m n}\right)\right].$

# %% [markdown]
# file: num8.png
#
# ![num8.png](attachment:num8.png)

# %%
file = "num8.png"
img = Image.open(file)

model = LatexOCR()
b = model(img)
print(b)
display(Latex(f"$%s$"%b))
# Out:
# \operatorname*{lim}_{x\rightarrow2}x^{2}+\Sigma
# $\operatorname*{lim}_{x\rightarrow2}x^{2}+\Sigma$
